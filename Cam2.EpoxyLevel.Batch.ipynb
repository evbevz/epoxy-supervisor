# %% [markdown]
# <a href="https://colab.research.google.com/github/evbevz/epoxy-supervisor/blob/main/EpoxyLevel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
try:
    import google.colab
    IS_COLAB_ENV = True
except:
    IS_COLAB_ENV = False
if IS_COLAB_ENV:
    # %pip install ultralytics
    # !git clone https://github.com/evbevz/epoxy-supervisor.git
    dirBase = '/content/drive/MyDrive/Colab Notebooks/'

    from google.colab import drive
    drive.mount('/content/drive/')
else:
    dirBase = '/home/nikolay/opencv/'
# %cd "{dirBase}epoxy-supervisor/"

# %%
import epoxylib
import os
from ultralytics import YOLO

# Значение уверенности в правильности распознавания, ниже которого не будем считать, что точки определились правильно. Т.е. координаты такой точки будем считать ложными и точку игнорировать.
kptConfidence = 0.8 # Сейчас точки если и распознаются, то с уверенностью больше 0.9

# Калибровочный файл в котором хранятся уровни от 0 до 20мл. В виде координат X,Y центра эллипса поверхности эпоксидки на каждом уровне.
filenameAnnotation = dirBase + 'epoxy-supervisor/samples/EpoxyLevelCalibrate.Cam2.Annotations.xml'

# Файл весов обученной для распознавания модели
#filenameAIModel = dirBase + 'epoxy-supervisor/weights/epoxy-supervisor.20241228.best.pt'
#filenameAIModel = dirBase + 'epoxy-supervisor/weights/es.yolo11s-pose.20250121.epoch400.pt'
#filenameAIModel = dirBase + 'epoxy-supervisor/weights/es.yolo11s-pose.20250213.best.pt'
filenameAIModel = dirBase + 'epoxy-supervisor/weights/es.onepoint.yolo11s-pose.20250317.best.pt'

# Изображение для предсказания уровня эпоксидки
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00048.png' #20
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00060.png' #20
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00110.png' #19
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00120.png' #18
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00175.png' #17
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00227.png' #16
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00311.png' #15
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00409.png' #14
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00508.png' #13
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00582.png' #12
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00668.png' #11
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00751.png' #10
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00843.png' # 9
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00951.png' # 8
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-01035.png' # 7
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-01168.png' # 6
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-01298.png' # 5
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-01434.png' # 4
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-01533.png' # 3
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-01635.png' # 2
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-01808.png' # 1
#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-02070.png' # 0

#filenameInjectorCam = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test/lvl3-00668.png'

# Калибруем шприц
arrayEpoxyLevel = epoxylib.Calibrate(filenameAnnotation)

# Загружаем модель
model = YOLO(filenameAIModel)

# Запрос уровня по изображению
#level = 20
#level = epoxylib.GetEpoxyLevel(model, arrayEpoxyLevel, filenameInjectorCam, kptConfidence, level)
#print (f"Уровень эпоксидки: {level}")

# %%
# Постороения списка уровней по изображениям в папке
#dataPath = dirBase + 'epoxy-supervisor/lvl-test/frames'
dataPath = dirBase + 'epoxy-supervisor/datasets/cam2.lvl3.one-point-ds/images/test'
data = os.listdir(dataPath)
data.sort()
levels = []
index_with_none = []
level = 20
for i, file in enumerate(data):
    fullPath = f"{dataPath}/{file}"
    level = epoxylib.GetEpoxyLevel(model, arrayEpoxyLevel, fullPath , kptConfidence, level)
    levels.append(level)
    if level is not None:
        print (f"Файл: {file}. Уровень эпоксидки: {level:.2f}")
    else:
        index_with_none.append(i)
        print (f"Файл: {file}. УРОВЕНЬ ЭПОКСИДКИ: NONE !!!")
# Out:
# Файл: lvl-00001.png. Уровень эпоксидки: 20.00
# Файл: lvl-00002.png. Уровень эпоксидки: 20.00
# Файл: lvl-00003.png. Уровень эпоксидки: 20.00
# Файл: lvl-00004.png. Уровень эпоксидки: 20.00
# Файл: lvl-00005.png. Уровень эпоксидки: 20.00
# Файл: lvl-00006.png. Уровень эпоксидки: 20.00
# Файл: lvl-00007.png. Уровень эпоксидки: 20.00
# Файл: lvl-00008.png. Уровень эпоксидки: 20.00
# Файл: lvl-00009.png. Уровень эпоксидки: 20.00
# Файл: lvl-00010.png. Уровень эпоксидки: 20.00
# Файл: lvl-00011.png. Уровень эпоксидки: 20.00
# Файл: lvl-00012.png. Уровень эпоксидки: 20.00
# Файл: lvl-00013.png. Уровень эпоксидки: 20.00
# Файл: lvl-00014.png. Уровень эпоксидки: 20.00
# Файл: lvl-00015.png. Уровень эпоксидки: 20.00
# Файл: lvl-00016.png. Уровень эпоксидки: 20.00
# Файл: lvl-00017.png. Уровень эпоксидки: 20.00
# Файл: lvl-00018.png. Уровень эпоксидки: 20.00
# Файл: lvl-00019.png. Уровень эпоксидки: 20.00
# Файл: lvl-00020.png. Уровень эпоксидки: 20.00
# Файл: lvl-00021.png. Уровень эпоксидки: 20.00
# Файл: lvl-00022.png. Уровень эпоксидки: 20.00
# Файл: lvl-00023.png. Уровень эпоксидки: 20.00
# Файл: lvl-00024.png. Уровень эпоксидки: 20.00
# Файл: lvl-00025.png. Уровень эпоксидки: 20.00
# Файл: lvl-00026.png. Уровень эпоксидки: 20.00
# Файл: lvl-00027.png. Уровень эпоксидки: 20.00
# Файл: lvl-00028.png. Уровень эпоксидки: 20.00
# Файл: lvl-00029.png. Уровень эпоксидки: 20.00
# Файл: lvl-00030.png. Уровень эпоксидки: 20.00
# Файл: lvl-00031.png. Уровень эпоксидки: 20.00
# Файл: lvl-00032.png. Уровень эпоксидки: 20.00
# Файл: lvl-00033.png. Уровень эпоксидки: 20.00
# Файл: lvl-00034.png. Уровень эпоксидки: 20.00
# Файл: lvl-00035.png. Уровень эпоксидки: 20.00
# Файл: lvl-00036.png. Уровень эпоксидки: 20.00
# Файл: lvl-00037.png. Уровень эпоксидки: 20.00
# Файл: lvl-00038.png. Уровень эпоксидки: 20.00
# Файл: lvl-00039.png. Уровень эпоксидки: 20.00
# Файл: lvl-00040.png. Уровень эпоксидки: 20.00
# Файл: lvl-00041.png. Уровень эпоксидки: 20.00
# Файл: lvl-00042.png. Уровень эпоксидки: 20.00
# Файл: lvl-00043.png. Уровень эпоксидки: 20.00
# Файл: lvl-00044.png. Уровень эпоксидки: 20.00
# Файл: lvl-00045.png. Уровень эпоксидки: 20.00
# Файл: lvl-00046.png. Уровень эпоксидки: 20.00
# Файл: lvl-00047.png. Уровень эпоксидки: 20.00
# Файл: lvl-00048.png. Уровень эпоксидки: 20.00
# Файл: lvl-00049.png. Уровень эпоксидки: 20.00
# Файл: lvl-00050.png. Уровень эпоксидки: 20.00
# Файл: lvl-00051.png. Уровень эпоксидки: 20.00
# Файл: lvl-00052.png. Уровень эпоксидки: 20.00
# Файл: lvl-00053.png. Уровень эпоксидки: 20.00
# Файл: lvl-00054.png. Уровень эпоксидки: 20.00
# Файл: lvl-00055.png. Уровень эпоксидки: 20.00
# Файл: lvl-00056.png. Уровень эпоксидки: 20.00
# Файл: lvl-00057.png. Уровень эпоксидки: 20.00
# Файл: lvl-00058.png. Уровень эпоксидки: 20.00
# Файл: lvl-00059.png. Уровень эпоксидки: 20.00
# Файл: lvl-00060.png. Уровень эпоксидки: 20.00
# Файл: lvl-00061.png. Уровень эпоксидки: 20.00
# Файл: lvl-00062.png. Уровень эпоксидки: 20.00
# Файл: lvl-00063.png. Уровень эпоксидки: 20.00
# Файл: lvl-00064.png. Уровень эпоксидки: 20.00
# Файл: lvl-00065.png. Уровень эпоксидки: 20.00
# Файл: lvl-00066.png. Уровень эпоксидки: 20.00
# Файл: lvl-00067.png. Уровень эпоксидки: 20.00
# Файл: lvl-00068.png. Уровень эпоксидки: 20.00
# Файл: lvl-00069.png. Уровень эпоксидки: 20.00
# Файл: lvl-00070.png. Уровень эпоксидки: 20.00
# Файл: lvl-00071.png. Уровень эпоксидки: 20.00
# Файл: lvl-00072.png. Уровень эпоксидки: 20.00
# Файл: lvl-00073.png. Уровень эпоксидки: 20.00
# Файл: lvl-00074.png. Уровень эпоксидки: 20.00
# Файл: lvl-00075.png. Уровень эпоксидки: 20.00
# Файл: lvl-00076.png. Уровень эпоксидки: 20.00
# Файл: lvl-00077.png. Уровень эпоксидки: 20.00
# Файл: lvl-00078.png. Уровень эпоксидки: 20.00
# Файл: lvl-00079.png. Уровень эпоксидки: 20.00
# Файл: lvl-00080.png. Уровень эпоксидки: 20.00
# Файл: lvl-00081.png. Уровень эпоксидки: 20.00
# Файл: lvl-00082.png. Уровень эпоксидки: 20.00
# Файл: lvl-00083.png. Уровень эпоксидки: 20.00
# Файл: lvl-00084.png. Уровень эпоксидки: 20.00
# Файл: lvl-00085.png. Уровень эпоксидки: 20.00
# Файл: lvl-00086.png. Уровень эпоксидки: 20.00
# Файл: lvl-00087.png. Уровень эпоксидки: 20.00
# Файл: lvl-00088.png. Уровень эпоксидки: 20.00
# Файл: lvl-00089.png. Уровень эпоксидки: 20.00
# Файл: lvl-00090.png. Уровень эпоксидки: 20.00
# Файл: lvl-00091.png. Уровень эпоксидки: 20.00
# Файл: lvl-00092.png. Уровень эпоксидки: 20.00
# Файл: lvl-00093.png. Уровень эпоксидки: 20.00
# Файл: lvl-00094.png. Уровень эпоксидки: 20.00
# Файл: lvl-00095.png. Уровень эпоксидки: 20.00
# Файл: lvl-00096.png. Уровень эпоксидки: 20.00
# Файл: lvl-00097.png. Уровень эпоксидки: 20.00
# Файл: lvl-00098.png. Уровень эпоксидки: 20.00
# Файл: lvl-00099.png. Уровень эпоксидки: 20.00
# Файл: lvl-00100.png. Уровень эпоксидки: 20.00
# Файл: lvl-00101.png. Уровень эпоксидки: 20.00
# Файл: lvl-00102.png. Уровень эпоксидки: 20.00
# Файл: lvl-00103.png. Уровень эпоксидки: 20.00
# Файл: lvl-00104.png. Уровень эпоксидки: 20.00
# Файл: lvl-00105.png. Уровень эпоксидки: 20.00
# Файл: lvl-00106.png. Уровень эпоксидки: 20.00
# Файл: lvl-00107.png. Уровень эпоксидки: 20.00
# Файл: lvl-00108.png. Уровень эпоксидки: 20.00
# Файл: lvl-00109.png. Уровень эпоксидки: 20.00
# Файл: lvl-00110.png. Уровень эпоксидки: 20.00
# Файл: lvl-00111.png. Уровень эпоксидки: 20.00
# Файл: lvl-00112.png. Уровень эпоксидки: 20.00
# Файл: lvl-00113.png. Уровень эпоксидки: 20.00
# Файл: lvl-00114.png. Уровень эпоксидки: 20.00
# Файл: lvl-00115.png. Уровень эпоксидки: 20.00
# Файл: lvl-00116.png. Уровень эпоксидки: 20.00
# Файл: lvl-00117.png. Уровень эпоксидки: 20.00
# Файл: lvl-00118.png. Уровень эпоксидки: 20.00
# Файл: lvl-00119.png. Уровень эпоксидки: 20.00
# Файл: lvl-00120.png. Уровень эпоксидки: 20.00
# Файл: lvl-00121.png. Уровень эпоксидки: 20.00
# Файл: lvl-00122.png. Уровень эпоксидки: 20.00
# Файл: lvl-00123.png. Уровень эпоксидки: 20.00
# Файл: lvl-00124.png. Уровень эпоксидки: 20.00
# Файл: lvl-00125.png. Уровень эпоксидки: 20.00
# Файл: lvl-00126.png. Уровень эпоксидки: 20.00
# Файл: lvl-00127.png. Уровень эпоксидки: 20.00
# Файл: lvl-00128.png. Уровень эпоксидки: 20.00
# Файл: lvl-00129.png. Уровень эпоксидки: 20.00
# Файл: lvl-00130.png. Уровень эпоксидки: 20.00
# Файл: lvl-00131.png. Уровень эпоксидки: 20.00
# Файл: lvl-00132.png. Уровень эпоксидки: 20.00
# Файл: lvl-00133.png. Уровень эпоксидки: 20.00
# Файл: lvl-00134.png. Уровень эпоксидки: 20.00
# Файл: lvl-00135.png. Уровень эпоксидки: 20.00
# Файл: lvl-00136.png. Уровень эпоксидки: 20.00
# Файл: lvl-00137.png. Уровень эпоксидки: 20.00
# Файл: lvl-00138.png. Уровень эпоксидки: 20.00
# Файл: lvl-00139.png. Уровень эпоксидки: 20.00
# Файл: lvl-00140.png. Уровень эпоксидки: 20.00
# Файл: lvl-00141.png. Уровень эпоксидки: 20.00
# Файл: lvl-00142.png. Уровень эпоксидки: 20.00
# Файл: lvl-00143.png. Уровень эпоксидки: 20.00
# Файл: lvl-00144.png. Уровень эпоксидки: 20.00
# Файл: lvl-00145.png. Уровень эпоксидки: 20.00
# Файл: lvl-00146.png. Уровень эпоксидки: 20.00
# Файл: lvl-00147.png. Уровень эпоксидки: 20.00
# Файл: lvl-00148.png. Уровень эпоксидки: 20.00
# Файл: lvl-00149.png. Уровень эпоксидки: 20.00
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 11
#       9 for i, file in enumerate(data):
#      10     fullPath = f"{dataPath}/{file}"
# ---> 11     level = epoxylib.GetEpoxyLevel(model, arrayEpoxyLevel, fullPath , kptConfidence, level)
#      12     levels.append(level)
#      13     if level is not None:
#
# File ~/opencv/epoxy-supervisor/epoxylib.py:139, in GetEpoxyLevel(model, arrayEpoxyLevel, filenameInjectorCam, kptConfidence, level_prev)
#     136         level_near_prev = level_cur                 # Запоминаем уровень ближайший к предыдущему
#     137     #print (f"Previous lvl: {level_prev},\tCurrent lvl: {level_cur},\tLength between: {length}\tMin length: {length_min}")
#     138 #print (f"Ближайший уровень эпоксидки: {level_near_prev}")
# --> 139 return level_near_prev
#
# UnboundLocalError: cannot access local variable 'level_near_prev' where it is not associated with a value

# %%
for i in index_with_none:
    print (f"Индекс: {i},\tФайл: {data[i]}. УРОВЕНЬ ЭПОКСИДКИ: NONE !!!")
    levels[i] = 0

# %%
# https://www.delftstack.com/howto/python/smooth-data-in-python/
import numpy as np
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt
import pandas as pd

# Применение фильтра Савицкого-Голея для сглаживания
#levels_savgol = savgol_filter(levels, 11, 3)
levels_savgol = savgol_filter(levels, 50, 3)

# Метод скользящего среднего
# Простой и проверенный метод сглаживания — скользящее среднее. Он балансирует между скоростью вычислений и точностью границ данных.
# Использование функции np.cumsum для подсчёта скользящего среднего обеспечивает быстроту, но может приводить к краевым эффектам.
# Метод np.convolve с параметром mode='same' предотвращает изменение размера массива и позволяет сравнить сглаженные данные с исходными.
levels_cumsum = np.cumsum(levels)
levels_convolve = np.convolve(levels,1,mode='same')

#
levels_pd = pd.Series(levels).rolling(window=50, center=True).mean()

#from operator import sub
#delta = map(sub,levels,levels_pd)
delta = np.array(levels) - np.array(levels_pd)

plt.plot(levels, label='Исходные данные')
plt.plot(levels_pd, color='red', label='Сглаженные данные')
#plt.plot(delta, color='green', label='Разница от среднего')
plt.legend()
plt.show()
